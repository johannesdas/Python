# %%
#Importing relevant libraries.

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
#Reading data.

df = pd.read_csv(r"C:\Data Science\Datasets\movies.csv")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Checking for number of missing values.

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Changing data types to int.

df['votes'] = df['votes'].fillna(0)
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0) 
df['runtime'] = df['runtime'].fillna(0)

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
#Dropping duplicates.

df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
#Correlation statistics.

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Revenue')
plt.xlabel('Budget')
plt.ylabel('Gross Revenue')
plt.show()

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#Brief look at correlations.

df.corr()
# Out:
# C:\Users\dchit\AppData\Local\Temp\ipykernel_23356\4236453157.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222427  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222427  0.409182  1.000000  0.486931  0.632870  0.309122
# budget   0.309212  0.055665  0.486931  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632870  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309122  0.269510  0.245235  1.000000

# %%
corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix')
plt.xlabel('Film Characteristics')
plt.ylabel('Film Characteristics')
# Out:
# C:\Users\dchit\AppData\Local\Temp\ipykernel_23356\3483281785.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# Text(120.72222222222221, 0.5, 'Film Characteristics')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
for col_name in df:
    if(df[col_name].dtype == 'object'):
        print(col_name)
# Out:
# name
# rating
# genre
# released
# director
# writer
# star
# country
# company

# %%
df_numericized = df

for col_name in df_numericized.columns:
    if(df_numericized[col_name].dtype == 'object'):
        df_numericized[col_name] = df_numericized[col_name].astype('category')
        df_numericized[col_name] = df_numericized[col_name].cat.codes

df_numericized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000      1111    2567
# 3      286       4      4  1980      1492    7.7   221000      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000      1054     521
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36       774    2614
# 7665  4717      -1      6  2020       193    5.7       29      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        0      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7      2165    3344
#
# ...

# %%
corr_matrix2 = df_numericized.corr()

sns.heatmap(corr_matrix2, annot=True)

plt.title('Correlation Matrix')
plt.xlabel('Film Characteristics')
plt.ylabel('Film Characteristics')
# Out:
# Text(120.72222222222221, 0.5, 'Film Characteristics')

# %%
#Highest correlative factors for Gross Revenue are Budget (0.75) and Votes (0.63).
